# %%
import numpy as np
import pandas as pd
dict1={
  "names":["avi","ram","lakshmi","ammu"],
  "marks":[23,45,67,89],
  "city":["hyd","bang","chennai","delhi"]
}
df=pd.DataFrame(dict1)
df

df.to_csv('avi.csv')
df.to_csv('avi.csv',index=False)

df['marks'][0]=42
df

df.index=['a','b','c','d']
df

ser=pd.Series(np.random.rand(34)) 
ser

newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newdf
newdf.head()
newdf.tail()
type(newdf)
newdf.describe()
newdf.dtypes
newdf[0][0]="avi"
newdf.dtypes
newdf.head()
newdf.index
newdf.columns
newdf.to_numpy()
newdf[0][0]=0.3
newdf.head()
newdf.to_numpy()
newdf.T
newdf.sort_index(axis=0,ascending=False)
newdf[0]
type(newdf[0])

newdf2=newdf
newdf2[0][0]=0.3
newdf

newdf1=newdf.copy()
newdf1[0][0]=9876
newdf1
newdf

newdf.loc[0,0]=654
newdf

newdf.columns=list("abcde")
newdf

newdf.loc[[1,2],['c','d']]

newdf.drop('e',axis=1)

newdf.loc[:,['a','b']]

newdf.loc[(newdf['a']<0.3)&(newdf['c']>0.1)]

newdf.iloc[0,4]
newdf.iloc[[0,1],[1,2]]
newdf.drop([0])
# Out:
# C:\Users\NALLA\AppData\Local\Temp\ipykernel_6888\546253714.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['marks'][0]=42
# C:\Users\NALLA\AppData\Local\Temp\ipykernel_6888\546253714.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marks'][0]=42
# C:\Users\NALLA\AppData\Local\Temp\ipykernel_6888\546253714.py:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf[0][0]="avi"
# C:\Users\NALLA\AppData\Local\Temp\ipykernel_6888\546253714.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'avi' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf[0][0]="avi"
# C:\Users\NALLA\AppData\Local\Temp\ipykernel_6888\546253714.py:49: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf1[0][0]=9876
# C:\Users\NALLA\AppData\Local\Temp\ipykernel_6888\546253714.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf1[0][0]=9876
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 71
#      68 newdf.iloc[[0,1],[1,2]]
#      69 newdf.drop([0])
# ---> 71 df3=pd.DataFrame({"name":['ammu','shiridi','thresa'],"toy":[np.nan,'baseball','cricket'],"born":[pd.NaT,pd.timestamp("1940-04-25"),pd.NaT]})
#      72 df3
#
# AttributeError: module 'pandas' has no attribute 'timestamp'
